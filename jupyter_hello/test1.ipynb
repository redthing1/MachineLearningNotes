# %% [markdown]
# # Hey hey people!
# Buckling up is **totes yeet yo**

# %% [markdown]
# ## First things
#
# we're going to test a simple sine wave plot

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('seaborn-pastel')
import math

# %%
x = np.arange(0, math.pi * 2, 0.05)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("sine wave")
ax.set_xlabel("angle")
ax.set_ylabel("sine")
# Out:
# Text(0, 0.5, 'sine')

# %% [markdown]
# ## Neural Network demo
#
# Okay, now we're going to mess around with **Keras**.
#
# Let's start with a simple neural network to learn XOR.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np 

x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('selu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr = 0.6, momentum = 0.6)
model.compile(loss='mean_squared_error', optimizer=sgd)

# %%
# train
model.fit(x, y, batch_size=8, epochs=200, verbose=1)
sample_probs = model.predict_proba(x)
print(sample_probs)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 102ms/step - loss: 0.2454
# Epoch 2/200
# 4/4 [==============================] - 0s 542us/step - loss: 0.2428
# Epoch 3/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2394
# Epoch 4/200
# 4/4 [==============================] - 0s 477us/step - loss: 0.2356
# Epoch 5/200
# 4/4 [==============================] - 0s 564us/step - loss: 0.2336
# Epoch 6/200
# 4/4 [==============================] - 0s 648us/step - loss: 0.2324
# Epoch 7/200
# 4/4 [==============================] - 0s 434us/step - loss: 0.2312
# Epoch 8/200
# 4/4 [==============================] - 0s 528us/step - loss: 0.2299
# Epoch 9/200
# 4/4 [==============================] - 0s 445us/step - loss: 0.2288
# Epoch 10/200
# 4/4 [==============================] - 0s 476us/step - loss: 0.2279
# Epoch 11/200
# 4/4 [==============================] - 0s 489us/step - loss: 0.2268
# Epoch 12/200
# ...

# %%
import itertools

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
labels = ["0 XOR 0","0 XOR 1","1 XOR 0", "1 XOR 1"]
ax.bar(labels, list(itertools.chain(*sample_probs)))
# Out:
# <BarContainer object of 4 artists>
